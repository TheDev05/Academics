# %% [markdown]
# <a href="https://colab.research.google.com/github/TheDev05/Semester_7/blob/main/23rd%20Aug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Get the path to the image file
image_path = "/elon.jpg"
plt.axis("off")

# Read the image file
image = plt.imread(image_path)

# Display the image
plt.title("Elon Musk")
plt.imshow(image)
plt.show()

# %%
import cv2
resized_image = cv2.resize(image,(300, 200))
plt.imshow(resized_image)
plt.show()

# %%
resized_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(resized_image)
plt.show()

# %% [markdown]
# gradient, orientaion
# gradient: change in magnitute x or y
# orientation: 1 ratio 2, height vs width
# convert ratio to patches, 64:128 => 8*8, divide ratio by 8
#
# image convert in histogram of 8*8 patches
