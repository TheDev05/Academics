# %% [markdown]
# <a href="https://colab.research.google.com/github/TheDev05/Semester_7/blob/main/Face%20%26%20Eye%20detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#REQUIRED LIBRARIES
import numpy as np
import cv2
from matplotlib import pyplot as plt

#FOR ACCESSING THE HAARASCADE FILE
# eye_classifier=cv2.CascadeClassifier('/content/haarcascade_frontalface_default.xml')
eye_classifier=cv2.CascadeClassifier('/content/haarcascade_eye.xml')

#TO DISPLAY THE IMAGE
image=cv2.imread('prashant.jpeg')
fix_img=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)


#SETTING THE SIZE AND COLOUR OF THE RECTANGLE BOXES
def detect_eyes(fix_img):
    eye_rects=eye_classifier.detectMultiScale(fix_img)
    for (ix,iy,iw,ih) in eye_rects:
        cv2.rectangle(fix_img,
                     (ix,iy),
                     (ix+iw,iy+ih),
                     (0,0,0),7)
    return fix_img


#TO DISPLAY THE FINAL IMAGE WITH EYES DETECTED
result=detect_eyes(fix_img)
plt.imshow(result)
